# %%
import selenium
import time as timelib
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
wd=webdriver.Chrome()
wd.get('https://www.linkedin.com/jobs/search/?currentJobId=3702297562&distance=25&geoId=102713980&keywords=artificial%20intelligence')


el=wd.find_element(By.NAME,'keywords')

for i in range(400):
    el.send_keys(Keys.PAGE_DOWN)
    timelib.sleep(.2)

timelib.sleep(5)
source=wd.page_source

wd.quit()

# %%
# Extract Basic Information
from bs4 import BeautifulSoup

soup = BeautifulSoup(source, 'lxml')
data=soup.find_all('div', class_='base-search-card__info')

title=[]
Location=[]
time=[]
date=[]
Company_Name=[]
description = []
for i in soup.findAll('time'):
        if i.has_attr('datetime'):
            time.append(i.get_text().strip())
            date.append(i['datetime'])

for i in data:
#     print('hello',i)
    h3=i.find('h3', class_='base-search-card__title').get_text()
    title.append(h3.strip())
    
    h4=i.find('h4', class_='base-search-card__subtitle').get_text()
    Company_Name.append(h4.strip())
    
    spanl=i.find('span', class_="job-search-card__location").get_text()
    Location.append(spanl.strip())
    
#     hire=i.find('span',class_='result-benefits__text').get_text()
#     hiring.append(hire.strip())

#     comp=i.find('a',class_='hidden-nested-link').get_text()
#     Company_Name.append(comp.strip())

# %%
wd=webdriver.Chrome()
wd.get('https://www.linkedin.com/jobs/view/junior-data-scientist-iit-bits-at-whitetable-ai-previously-as-iie-network-3683112838/?trackingId=w1PwQRucThUnX2X1%2FoX63A%3D%3D&refId=fiVhotFXE3tX57IYht5ELg%3D%3D&pageNum=0&position=1&trk=public_jobs_jserp-result_search-card&originalSubdomain=in')
show_more_buttons = wd.find_elements(By.CLASS_NAME, "")
if show_more_buttons:
    # Assuming you want to click the first matching button, you can change the index if needed
    show_more_buttons[0].click()

# %%
wd=webdriver.Chrome()

wd.get("https://www.linkedin.com/jobs/view/junior-data-scientist-iit-bits-at-whitetable-ai-previously-as-iie-network-3683112838/?trackingId=w1PwQRucThUnX2X1%2FoX63A%3D%3D&refId=fiVhotFXE3tX57IYht5ELg%3D%3D&pageNum=0&position=1&trk=public_jobs_jserp-result_search-card&originalSubdomain=in")


# Locate and click the "Show More" button by its class name
try:
    show_more_buttons = wd.find_elements(By.CLASS_NAME, "show-more-less-html__button")
    if show_more_buttons:
        # Assuming you want to click the first matching button, you can change the index if needed
        show_more_buttons[0].click()
    else:
        print("No 'Show More' buttons found.")
except Exception as e:
    print("Error clicking the 'Show More' button:", str(e))

des=wd.page_source

# Close the WebDriver when done
wd.quit()

# %%
soup = BeautifulSoup(des)
info = soup.find_all('ul')
info
# Out:
# [<ul class="switcher-tabs__list flex flex-1 items-stretch papabear:flex-col mamabear:flex-col" role="tablist">
#  <li class="switcher-tabs__tab h-[44px] babybear:basis-1/2" role="presentation">
#  <button aria-controls="jobs-search-panel" aria-selected="true" class="switcher-tabs__button w-full h-full tab-md papabear:tab-vertical mamabear:tab-vertical papabear:justify-start mamabear:justify-start cursor-pointer tab-selected" data-switcher-type="JOBS" data-tracking-control-name="public_jobs_switcher-tabs-jobs-search-switcher" id="job-switcher-tab" role="tab">
#                          Jobs
#                      </button>
#  </li>
#  <li class="switcher-tabs__tab h-[44px] babybear:basis-1/2" role="presentation">
#  <button aria-controls="people-search-panel" aria-selected="false" class="switcher-tabs__button w-full h-full tab-md papabear:tab-vertical mamabear:tab-vertical papabear:justify-start mamabear:justify-start cursor-pointer" data-switcher-type="PEOPLE" data-tracking-control-name="public_jobs_switcher-tabs-people-search-switcher" id="people-switcher-tab" role="tab">
#                          People
#                      </button>
#  </li>
#  <li class="switcher-tabs__tab h-[44px] babybear:basis-1/2" role="presentation">
#  <button aria-controls="posts-search-panel" aria-selected="false" class="switcher-tabs__button w-full h-full tab-md papabear:tab-vertical mamabear:tab-vertical papabear:justify-start mamabear:justify-start cursor-pointer" data-switcher-type="POSTS" data-tracking-control-name="public_jobs_switcher-tabs-posts-search-switcher" id="posts-switcher-tab" role="tab">
#                          Posts
#                                            </button>
#  </li>
#  <li class="switcher-tabs__tab h-[44px] babybear:basis-1/2" role="presentation">
#  <button aria-controls="learning-search-panel" aria-selected="false" class="switcher-tabs__button w-full h-full tab-md papabear:tab-vertical mamabear:tab-vertical papabear:justify-start mamabear:justify-start cursor-pointer" data-switcher-type="LEARNING" data-tracking-control-name="public_jobs_switcher-tabs-learning-search-switcher" id="learning-switcher-tab" role="tab">
#                          Learning
#                      </button>
#  </li>
#  </ul>,
#  <ul class="typeahead-input__dropdown-list w-full" id="job-search-bar-keywords-typeahead-list" role="listbox"></ul>,
#  <ul class="typeahead-input__dropdown-list w-full" id="job-search-bar-location-typeahead-list" role="listbox"></ul>,
#  <ul class="collapsible-dropdown__list hidden container-raised absolute w-auto overflow-y-auto flex-col items-stretch z-1 bottom-auto top-[100%]" role="menu" tabindex="-1">
#  <li class="ellipsis-menu__item border-t-1 border-solid border-color-border-low-emphasis first-of-type:border-none flex">
#  <a class="semaphore__toggle visited:text-color-text-secondary ellipsis-menu__semaphore ellipsis-menu__item-button flex items-center w-full p-1 cursor-pointer font-sans text-sm font-bold link-styled focus:link-styled link:no-underline active:bg-color-background-container-tint focus:bg-color-background-container-tint hover:bg-color-background-container-tint outline-offset-[-2px]" data-is-logged-in="false" data-item-type="semaphore" data-modal="semaphore__toggle" data-semaphore-content-type="JOB" data-semaphore-content-urn="urn:li:jobPosting:3683112838" data-semaphore-tracking-prefix="public_jobs_ellipsis-menu-semaphore" data-tracking-control-name="public_jobs_ellipsis-menu-semaphore-sign-in-redirect" data-tracking-will-navigate="" href="/uas/login?fromSignIn=true&amp;session_redirect=https%3A%2F%2Fin.linkedin.com%2Fjobs%2Fview%2Fjunior-data-scientist-iit-bits-at-whitetable-ai-previously-as-iie-network-3683112838%3FrefId%3DfiVhotFXE3tX57IYht5ELg%253D%253D%26trackingId%3Dw1PwQRucThUnX2X1%252FoX63A%253D%253D&amp;trk=public_jobs_ellipsis-menu-semaphore-sign-in-redirect&amp;guestReportContentType=JOB&amp;_f=guest-reporting">
#  <!-- -->
#  <icon aria-busy="false" aria-hidden="true" class="ellipsis-menu__item-icon text-color-text h-[24px] w-[24px] mr-1 lazy-loaded">
#  <svg aria-busy="false" class="lazy-loaded" data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path d="M13.82 5L14 4a1 1 0 00-1-1H5V2H3v20h2v-7h4.18L9 16a1 1 0 001 1h8.87L21 5h-7.18zM5 13V5h6.94l-1.41 8H5zm12.35 2h-6.3l1.42-8h6.29z"></path>
#  </svg></icon>
#                        Report this job
#
#      </a>
#  <!-- -->
#  </li>
#  <!-- -->
#  </ul>,
#  <ul><li>Utilize a range of machine learning algorithms to develop and implement predictive models, classification models, and other data-driven solutions to address business challenges.</li><li>Conduct thorough statistical analysis on large datasets to extract meaningful insights and trends that contribute to data-driven decision-making.</li><li>Collaborate with cross-functional teams to understand business requirements, gather data, and design experiments to test hypotheses.</li><li>Explore and experiment with new tools, technologies, and frameworks to enhance data science capabilities and efficiency.</li></ul>,
#  <ul><li>Bachelor's from IITs, NITs or BITS.</li><li>Minimum 1 year of professional experience in data science or related fields.</li><li>Strong knowledge and practical experience in various machine learning algorithms for classification, regression, clustering, and recommendation systems.</li><li>Proficiency in statistical analysis and data visualization tools such as Python, R, or similar.</li><li>Hands-on experience in backend development</li><li>A good understanding of data structures and algorithms</li><li>Familiarity with databases and SQL for data retrieval and manipulation.</li><li>Excellent problem-solving skills and the ability to think critically about complex data-related challenges.</li></ul>,
#  <ul><li> This is an excellent opportunity for a talented and passionate junior data scientist to join a dynamic team and contribute to cutting-edge data science projects.</li><li> If you meet the qualifications and have a strong desire to make a meaningful impact in the field of data science, we encourage you to apply and be part of our exciting journey.</li></ul>,
#  <ul class="description__job-criteria-list">
#  <li class="description__job-criteria-item">
#  <h3 class="description__job-criteria-subheader">
#              Seniority level
#            </h3>
#  <span class="description__job-criteria-text description__job-criteria-text--criteria">
#              Entry level
#            </span>
#  </li>
#  <li class="description__job-criteria-item">
#  <h3 class="description__job-criteria-subheader">
#            Employment type
#          </h3>
#  <span class="description__job-criteria-text description__job-criteria-text--criteria">
#            Full-time
#          </span>
#  </li>
#  <li class="description__job-criteria-item">
#  <h3 class="description__job-criteria-subheader">
#              Job function
#            </h3>
#  <span class="description__job-criteria-text description__job-criteria-text--criteria">
#              Information Technology
#            </span>
#  </li>
#  <li class="description__job-criteria-item">
#  <h3 class="description__job-criteria-subheader">
#              Industries
#            </h3>
#  <span class="description__job-criteria-text description__job-criteria-text--criteria">
#            Software Development, Technology, Information and Internet, and Data Infrastructure and Analytics
#            </span>
#  </li>
#  </ul>,
#  <ul class="show-more-less__list show-more-less__list--hide-after-6" data-impression-id="public_jobs_similar-jobs_show-more-less" data-max-num-to-show="6">
#  <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-main-card flex flex-wrap py-2 pr-2 babybear:pr-0 base-main-card--link main-job-card" data-entity-urn="urn:li:jobPosting:3690475337" data-impression-id="similar-jobs-0" data-reference-id="E1+mkhuEOyac0mRgdyDiSg==" data-tracking-id="H8kPD+u+f9xlyZjDtEbfvg==">
#  <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs" data-tracking-will-navigate="" href="https://in.linkedin.com/jobs/view/software-developer-at-arzooo-3690475337?refId=E1%2BmkhuEOyac0mRgdyDiSg%3D%3D&amp;trackingId=H8kPD%2Bu%2Bf9xlyZjDtEbfvg%3D%3D&amp;trk=public_jobs_similar-jobs">
#  <span class="sr-only">
#
#
#          Software Developer
#
#
#            </span>
#  </a>
#  <img alt="" class="inline-block relative w-6 h-6" data-delayed-url="https://media.licdn.com/dms/image/C4E0BAQHqqHVBNWFVpQ/company-logo_100_100/0/1601550951931?e=2147483647&amp;v=beta&amp;t=q4bDOnz23LCtMFnfCwedpm-vk9dUjO8aNx-QsclWB-U" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/eojn00s72k70vnw5r0xj92t9e"/>
#  <div class="base-main-card__info self-center ml-1 flex-1 relative break-words papabear:min-w-0 mamabear:min-w-0 babybear:w-full">
#  <h3 class="base-main-card__title font-sans text-[18px] font-bold text-color-text overflow-hidden">
#
#          Software Developer
#
#            </h3>
#  <h4 class="base-main-card__subtitle body-text text-color-text overflow-hidden">
#  <a class="hidden-nested-link outline-offset-[-1px]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs_main-jobs-card-subtitle" data-tracking-will-navigate="" href="https://in.linkedin.com/company/arzooo?trk=public_jobs_similar-jobs_main-jobs-card-subtitle">
#              Arzooo
#            </a>
#  </h4>
#  <!-- -->
#  <div class="body-text text-color-text-low-emphasis base-main-card__metadata">
#  <span class="main-job-card__location block mb-0.5 text-md leading-open font-normal text-color-text-low-emphasis">
#              Bengaluru, Karnataka, India
#            </span>
#  <!-- -->
#  <time class="main-job-card__listdate text-color-text-low-emphasis font-normal text-sm leading-open" datetime="2023-08-10">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        3 weeks ago
#
#            </time>
#  <!-- -->
#  </div>
#  </div>
#  <!-- -->
#  </div>
#  </li>
#  <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-main-card flex flex-wrap py-2 pr-2 babybear:pr-0 base-main-card--link main-job-card" data-entity-urn="urn:li:jobPosting:3707173835" data-impression-id="similar-jobs-1" data-reference-id="E1+mkhuEOyac0mRgdyDiSg==" data-tracking-id="wTMj85GU3PsjIJRhYnn01w==">
#  <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs" data-tracking-will-navigate="" href="https://in.linkedin.com/jobs/view/software-engineering-new-grad-at-stripe-3707173835?refId=E1%2BmkhuEOyac0mRgdyDiSg%3D%3D&amp;trackingId=wTMj85GU3PsjIJRhYnn01w%3D%3D&amp;trk=public_jobs_similar-jobs">
#  <span class="sr-only">
#
#
#          Software Engineering, New Grad
#
#
#            </span>
#  </a>
#  <img alt="" class="inline-block relative w-6 h-6" data-delayed-url="https://media.licdn.com/dms/image/C560BAQF1NNJs-2xA5g/company-logo_100_100/0/1594068219050?e=2147483647&amp;v=beta&amp;t=cEYoOLuoJEPoLCPN5nuAGF5G0iDoP9xOd1bCWvRcBLw" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/eojn00s72k70vnw5r0xj92t9e"/>
#  <div class="base-main-card__info self-center ml-1 flex-1 relative break-words papabear:min-w-0 mamabear:min-w-0 babybear:w-full">
#  <h3 class="base-main-card__title font-sans text-[18px] font-bold text-color-text overflow-hidden">
#
#          Software Engineering, New Grad
#
#            </h3>
#  <h4 class="base-main-card__subtitle body-text text-color-text overflow-hidden">
#  <a class="hidden-nested-link outline-offset-[-1px]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs_main-jobs-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/stripe?trk=public_jobs_similar-jobs_main-jobs-card-subtitle">
#              Stripe
#            </a>
#  </h4>
#  <!-- -->
#  <div class="body-text text-color-text-low-emphasis base-main-card__metadata">
#  <span class="main-job-card__location block mb-0.5 text-md leading-open font-normal text-color-text-low-emphasis">
#              Bengaluru, Karnataka, India
#            </span>
#  <!-- -->
#  <time class="main-job-card__listdate text-color-text-low-emphasis font-normal text-sm leading-open" datetime="2023-08-29">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        6 days ago
#
#            </time>
#  <!-- -->
#  </div>
#  </div>
#  <!-- -->
#  </div>
#  </li>
#  <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-main-card flex flex-wrap py-2 pr-2 babybear:pr-0 base-main-card--link main-job-card" data-entity-urn="urn:li:jobPosting:3685518795" data-impression-id="similar-jobs-2" data-reference-id="E1+mkhuEOyac0mRgdyDiSg==" data-tracking-id="r4Wp9CTImJZwOaTsZlgXfQ==">
#  <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs" data-tracking-will-navigate="" href="https://in.linkedin.com/jobs/view/software-engineer-freshers-0-1-years-hyderabad-aug-02-2023-19-54-50-at-pago-analytics-3685518795?refId=E1%2BmkhuEOyac0mRgdyDiSg%3D%3D&amp;trackingId=r4Wp9CTImJZwOaTsZlgXfQ%3D%3D&amp;trk=public_jobs_similar-jobs">
#  <span class="sr-only">
#
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 02,2023 19:54:50
#
#
#            </span>
#  </a>
#  <img alt="" class="inline-block relative w-6 h-6" data-delayed-url="https://media.licdn.com/dms/image/C510BAQGcSLTZcPdw-g/company-logo_100_100/0/1586848247435?e=2147483647&amp;v=beta&amp;t=RBpxjQJffTtMd3WADt4eoE6jBUEB_stRnqK7YGRybOM" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/eojn00s72k70vnw5r0xj92t9e"/>
#  <div class="base-main-card__info self-center ml-1 flex-1 relative break-words papabear:min-w-0 mamabear:min-w-0 babybear:w-full">
#  <h3 class="base-main-card__title font-sans text-[18px] font-bold text-color-text overflow-hidden">
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 02,2023 19:54:50
#
#            </h3>
#  <h4 class="base-main-card__subtitle body-text text-color-text overflow-hidden">
#  <a class="hidden-nested-link outline-offset-[-1px]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs_main-jobs-card-subtitle" data-tracking-will-navigate="" href="https://in.linkedin.com/company/pago-analytics?trk=public_jobs_similar-jobs_main-jobs-card-subtitle">
#              PAGO Analytics
#            </a>
#  </h4>
#  <!-- -->
#  <div class="body-text text-color-text-low-emphasis base-main-card__metadata">
#  <span class="main-job-card__location block mb-0.5 text-md leading-open font-normal text-color-text-low-emphasis">
#              Hyderabad, Telangana, India
#            </span>
#  <!-- -->
#  <time class="main-job-card__listdate text-color-text-low-emphasis font-normal text-sm leading-open" datetime="2023-08-04">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        1 month ago
#
#            </time>
#  <!-- -->
#  </div>
#  </div>
#  <!-- -->
#  </div>
#  </li>
#  <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-main-card flex flex-wrap py-2 pr-2 babybear:pr-0 base-main-card--link main-job-card" data-entity-urn="urn:li:jobPosting:3687677634" data-impression-id="similar-jobs-3" data-reference-id="E1+mkhuEOyac0mRgdyDiSg==" data-tracking-id="EBV1MwYTMQ1rjt6l0Hw38g==">
#  <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs" data-tracking-will-navigate="" href="https://in.linkedin.com/jobs/view/software-engineer-freshers-0-1-years-hyderabad-aug-07-2023-19-52-30-at-pago-analytics-3687677634?refId=E1%2BmkhuEOyac0mRgdyDiSg%3D%3D&amp;trackingId=EBV1MwYTMQ1rjt6l0Hw38g%3D%3D&amp;trk=public_jobs_similar-jobs">
#  <span class="sr-only">
#
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 07,2023 19:52:30
#
#
#            </span>
#  </a>
#  <img alt="" class="inline-block relative w-6 h-6" data-delayed-url="https://media.licdn.com/dms/image/C510BAQGcSLTZcPdw-g/company-logo_100_100/0/1586848247435?e=2147483647&amp;v=beta&amp;t=RBpxjQJffTtMd3WADt4eoE6jBUEB_stRnqK7YGRybOM" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/eojn00s72k70vnw5r0xj92t9e"/>
#  <div class="base-main-card__info self-center ml-1 flex-1 relative break-words papabear:min-w-0 mamabear:min-w-0 babybear:w-full">
#  <h3 class="base-main-card__title font-sans text-[18px] font-bold text-color-text overflow-hidden">
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 07,2023 19:52:30
#
#            </h3>
#  <h4 class="base-main-card__subtitle body-text text-color-text overflow-hidden">
#  <a class="hidden-nested-link outline-offset-[-1px]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs_main-jobs-card-subtitle" data-tracking-will-navigate="" href="https://in.linkedin.com/company/pago-analytics?trk=public_jobs_similar-jobs_main-jobs-card-subtitle">
#              PAGO Analytics
#            </a>
#  </h4>
#  <!-- -->
#  <div class="body-text text-color-text-low-emphasis base-main-card__metadata">
#  <span class="main-job-card__location block mb-0.5 text-md leading-open font-normal text-color-text-low-emphasis">
#              Hyderabad, Telangana, India
#            </span>
#  <!-- -->
#  <time class="main-job-card__listdate text-color-text-low-emphasis font-normal text-sm leading-open" datetime="2023-08-08">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        4 weeks ago
#
#            </time>
#  <!-- -->
#  </div>
#  </div>
#  <!-- -->
#  </div>
#  </li>
#  <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-main-card flex flex-wrap py-2 pr-2 babybear:pr-0 base-main-card--link main-job-card" data-entity-urn="urn:li:jobPosting:3682442177" data-impression-id="similar-jobs-4" data-reference-id="E1+mkhuEOyac0mRgdyDiSg==" data-tracking-id="lM2tM41HhdJhrdIzl/kLcw==">
#  <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs" data-tracking-will-navigate="" href="https://in.linkedin.com/jobs/view/software-engineer-freshers-0-1-years-hyderabad-aug-01-2023-19-56-54-at-pago-analytics-3682442177?refId=E1%2BmkhuEOyac0mRgdyDiSg%3D%3D&amp;trackingId=lM2tM41HhdJhrdIzl%2FkLcw%3D%3D&amp;trk=public_jobs_similar-jobs">
#  <span class="sr-only">
#
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 01,2023 19:56:54
#
#
#            </span>
#  </a>
#  <img alt="" class="inline-block relative w-6 h-6" data-delayed-url="https://media.licdn.com/dms/image/C510BAQGcSLTZcPdw-g/company-logo_100_100/0/1586848247435?e=2147483647&amp;v=beta&amp;t=RBpxjQJffTtMd3WADt4eoE6jBUEB_stRnqK7YGRybOM" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/eojn00s72k70vnw5r0xj92t9e"/>
#  <div class="base-main-card__info self-center ml-1 flex-1 relative break-words papabear:min-w-0 mamabear:min-w-0 babybear:w-full">
#  <h3 class="base-main-card__title font-sans text-[18px] font-bold text-color-text overflow-hidden">
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 01,2023 19:56:54
#
#            </h3>
#  <h4 class="base-main-card__subtitle body-text text-color-text overflow-hidden">
#  <a class="hidden-nested-link outline-offset-[-1px]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs_main-jobs-card-subtitle" data-tracking-will-navigate="" href="https://in.linkedin.com/company/pago-analytics?trk=public_jobs_similar-jobs_main-jobs-card-subtitle">
#              PAGO Analytics
#            </a>
#  </h4>
#  <!-- -->
#  <div class="body-text text-color-text-low-emphasis base-main-card__metadata">
#  <span class="main-job-card__location block mb-0.5 text-md leading-open font-normal text-color-text-low-emphasis">
#              Hyderabad, Telangana, India
#            </span>
#  <!-- -->
#  <time class="main-job-card__listdate text-color-text-low-emphasis font-normal text-sm leading-open" datetime="2023-08-02">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        1 month ago
#
#            </time>
#  <!-- -->
#  </div>
#  </div>
#  <!-- -->
#  </div>
#  </li>
#  <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-main-card flex flex-wrap py-2 pr-2 babybear:pr-0 base-main-card--link main-job-card" data-entity-urn="urn:li:jobPosting:3687020692" data-impression-id="similar-jobs-5" data-reference-id="E1+mkhuEOyac0mRgdyDiSg==" data-tracking-id="RFQhNWEyr74lxkifWzqOWA==">
#  <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs" data-tracking-will-navigate="" href="https://in.linkedin.com/jobs/view/software-engineer-freshers-0-1-years-hyderabad-aug-06-2023-19-53-34-at-pago-analytics-3687020692?refId=E1%2BmkhuEOyac0mRgdyDiSg%3D%3D&amp;trackingId=RFQhNWEyr74lxkifWzqOWA%3D%3D&amp;trk=public_jobs_similar-jobs">
#  <span class="sr-only">
#
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 06,2023 19:53:34
#
#
#            </span>
#  </a>
#  <img alt="" class="inline-block relative w-6 h-6" data-delayed-url="https://media.licdn.com/dms/image/C510BAQGcSLTZcPdw-g/company-logo_100_100/0/1586848247435?e=2147483647&amp;v=beta&amp;t=RBpxjQJffTtMd3WADt4eoE6jBUEB_stRnqK7YGRybOM" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/eojn00s72k70vnw5r0xj92t9e"/>
#  <div class="base-main-card__info self-center ml-1 flex-1 relative break-words papabear:min-w-0 mamabear:min-w-0 babybear:w-full">
#  <h3 class="base-main-card__title font-sans text-[18px] font-bold text-color-text overflow-hidden">
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 06,2023 19:53:34
#
#            </h3>
#  <h4 class="base-main-card__subtitle body-text text-color-text overflow-hidden">
#  <a class="hidden-nested-link outline-offset-[-1px]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs_main-jobs-card-subtitle" data-tracking-will-navigate="" href="https://in.linkedin.com/company/pago-analytics?trk=public_jobs_similar-jobs_main-jobs-card-subtitle">
#              PAGO Analytics
#            </a>
#  </h4>
#  <!-- -->
#  <div class="body-text text-color-text-low-emphasis base-main-card__metadata">
#  <span class="main-job-card__location block mb-0.5 text-md leading-open font-normal text-color-text-low-emphasis">
#              Hyderabad, Telangana, India
#            </span>
#  <!-- -->
#  <time class="main-job-card__listdate text-color-text-low-emphasis font-normal text-sm leading-open" datetime="2023-08-07">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        4 weeks ago
#
#            </time>
#  <!-- -->
#  </div>
#  </div>
#  <!-- -->
#  </div>
#  </li>
#  <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-main-card flex flex-wrap py-2 pr-2 babybear:pr-0 base-main-card--link main-job-card" data-entity-urn="urn:li:jobPosting:3689848873" data-impression-id="similar-jobs-6" data-reference-id="E1+mkhuEOyac0mRgdyDiSg==" data-tracking-id="ibpCyte9HVMi83jyJmE0Qw==">
#  <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs" data-tracking-will-navigate="" href="https://in.linkedin.com/jobs/view/software-engineer-freshers-0-1-years-hyderabad-aug-09-2023-20-08-25-at-pago-analytics-3689848873?refId=E1%2BmkhuEOyac0mRgdyDiSg%3D%3D&amp;trackingId=ibpCyte9HVMi83jyJmE0Qw%3D%3D&amp;trk=public_jobs_similar-jobs">
#  <span class="sr-only">
#
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 09,2023 20:08:25
#
#
#            </span>
#  </a>
#  <img alt="" aria-busy="false" class="inline-block relative w-6 h-6 lazy-loaded" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/eojn00s72k70vnw5r0xj92t9e" src="https://media.licdn.com/dms/image/C510BAQGcSLTZcPdw-g/company-logo_100_100/0/1586848247435?e=2147483647&amp;v=beta&amp;t=RBpxjQJffTtMd3WADt4eoE6jBUEB_stRnqK7YGRybOM"/>
#  <div class="base-main-card__info self-center ml-1 flex-1 relative break-words papabear:min-w-0 mamabear:min-w-0 babybear:w-full">
#  <h3 class="base-main-card__title font-sans text-[18px] font-bold text-color-text overflow-hidden">
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 09,2023 20:08:25
#
#            </h3>
#  <h4 class="base-main-card__subtitle body-text text-color-text overflow-hidden">
#  <a class="hidden-nested-link outline-offset-[-1px]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs_main-jobs-card-subtitle" data-tracking-will-navigate="" href="https://in.linkedin.com/company/pago-analytics?trk=public_jobs_similar-jobs_main-jobs-card-subtitle">
#              PAGO Analytics
#            </a>
#  </h4>
#  <!-- -->
#  <div class="body-text text-color-text-low-emphasis base-main-card__metadata">
#  <span class="main-job-card__location block mb-0.5 text-md leading-open font-normal text-color-text-low-emphasis">
#              Hyderabad, Telangana, India
#            </span>
#  <!-- -->
#  <time class="main-job-card__listdate text-color-text-low-emphasis font-normal text-sm leading-open" datetime="2023-08-11">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        3 weeks ago
#
#            </time>
#  <!-- -->
#  </div>
#  </div>
#  <!-- -->
#  </div>
#  </li>
#  <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-main-card flex flex-wrap py-2 pr-2 babybear:pr-0 base-main-card--link main-job-card" data-entity-urn="urn:li:jobPosting:3686164439" data-impression-id="similar-jobs-7" data-reference-id="E1+mkhuEOyac0mRgdyDiSg==" data-tracking-id="mXrvysHZgjWpQmom++StjA==">
#  <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs" data-tracking-will-navigate="" href="https://in.linkedin.com/jobs/view/software-engineer-freshers-0-1-years-hyderabad-aug-05-2023-19-51-41-at-pago-analytics-3686164439?refId=E1%2BmkhuEOyac0mRgdyDiSg%3D%3D&amp;trackingId=mXrvysHZgjWpQmom%2B%2BStjA%3D%3D&amp;trk=public_jobs_similar-jobs">
#  <span class="sr-only">
#
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 05,2023 19:51:41
#
#
#            </span>
#  </a>
#  <img alt="" aria-busy="false" class="inline-block relative w-6 h-6 lazy-loaded" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/eojn00s72k70vnw5r0xj92t9e" src="https://media.licdn.com/dms/image/C510BAQGcSLTZcPdw-g/company-logo_100_100/0/1586848247435?e=2147483647&amp;v=beta&amp;t=RBpxjQJffTtMd3WADt4eoE6jBUEB_stRnqK7YGRybOM"/>
#  <div class="base-main-card__info self-center ml-1 flex-1 relative break-words papabear:min-w-0 mamabear:min-w-0 babybear:w-full">
#  <h3 class="base-main-card__title font-sans text-[18px] font-bold text-color-text overflow-hidden">
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 05,2023 19:51:41
#
#            </h3>
#  <h4 class="base-main-card__subtitle body-text text-color-text overflow-hidden">
#  <a class="hidden-nested-link outline-offset-[-1px]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs_main-jobs-card-subtitle" data-tracking-will-navigate="" href="https://in.linkedin.com/company/pago-analytics?trk=public_jobs_similar-jobs_main-jobs-card-subtitle">
#              PAGO Analytics
#            </a>
#  </h4>
#  <!-- -->
#  <div class="body-text text-color-text-low-emphasis base-main-card__metadata">
#  <span class="main-job-card__location block mb-0.5 text-md leading-open font-normal text-color-text-low-emphasis">
#              Hyderabad, Telangana, India
#            </span>
#  <!-- -->
#  <time class="main-job-card__listdate text-color-text-low-emphasis font-normal text-sm leading-open" datetime="2023-08-06">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        1 month ago
#
#            </time>
#  <!-- -->
#  </div>
#  </div>
#  <!-- -->
#  </div>
#  </li>
#  <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-main-card flex flex-wrap py-2 pr-2 babybear:pr-0 base-main-card--link main-job-card" data-entity-urn="urn:li:jobPosting:3689848864" data-impression-id="similar-jobs-8" data-reference-id="E1+mkhuEOyac0mRgdyDiSg==" data-tracking-id="OyHb7mw4VqWP/r5TKaOw0A==">
#  <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs" data-tracking-will-navigate="" href="https://in.linkedin.com/jobs/view/software-engineer-freshers-0-1-years-hyderabad-aug-09-2023-20-08-25-at-pago-analytics-3689848864?refId=E1%2BmkhuEOyac0mRgdyDiSg%3D%3D&amp;trackingId=OyHb7mw4VqWP%2Fr5TKaOw0A%3D%3D&amp;trk=public_jobs_similar-jobs">
#  <span class="sr-only">
#
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 09,2023 20:08:25
#
#
#            </span>
#  </a>
#  <img alt="" aria-busy="false" class="inline-block relative w-6 h-6 lazy-loaded" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/eojn00s72k70vnw5r0xj92t9e" src="https://media.licdn.com/dms/image/C510BAQGcSLTZcPdw-g/company-logo_100_100/0/1586848247435?e=2147483647&amp;v=beta&amp;t=RBpxjQJffTtMd3WADt4eoE6jBUEB_stRnqK7YGRybOM"/>
#  <div class="base-main-card__info self-center ml-1 flex-1 relative break-words papabear:min-w-0 mamabear:min-w-0 babybear:w-full">
#  <h3 class="base-main-card__title font-sans text-[18px] font-bold text-color-text overflow-hidden">
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 09,2023 20:08:25
#
#            </h3>
#  <h4 class="base-main-card__subtitle body-text text-color-text overflow-hidden">
#  <a class="hidden-nested-link outline-offset-[-1px]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs_main-jobs-card-subtitle" data-tracking-will-navigate="" href="https://in.linkedin.com/company/pago-analytics?trk=public_jobs_similar-jobs_main-jobs-card-subtitle">
#              PAGO Analytics
#            </a>
#  </h4>
#  <!-- -->
#  <div class="body-text text-color-text-low-emphasis base-main-card__metadata">
#  <span class="main-job-card__location block mb-0.5 text-md leading-open font-normal text-color-text-low-emphasis">
#              Hyderabad, Telangana, India
#            </span>
#  <!-- -->
#  <time class="main-job-card__listdate text-color-text-low-emphasis font-normal text-sm leading-open" datetime="2023-08-11">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        3 weeks ago
#
#            </time>
#  <!-- -->
#  </div>
#  </div>
#  <!-- -->
#  </div>
#  </li>
#  <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-main-card flex flex-wrap py-2 pr-2 babybear:pr-0 base-main-card--link main-job-card" data-entity-urn="urn:li:jobPosting:3689025399" data-impression-id="similar-jobs-9" data-reference-id="E1+mkhuEOyac0mRgdyDiSg==" data-tracking-id="Vrvms44hIIGjoXLzDlXbPw==">
#  <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs" data-tracking-will-navigate="" href="https://in.linkedin.com/jobs/view/software-engineer-freshers-0-1-years-hyderabad-aug-08-2023-19-56-22-at-pago-analytics-3689025399?refId=E1%2BmkhuEOyac0mRgdyDiSg%3D%3D&amp;trackingId=Vrvms44hIIGjoXLzDlXbPw%3D%3D&amp;trk=public_jobs_similar-jobs">
#  <span class="sr-only">
#
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 08,2023 19:56:22
#
#
#            </span>
#  </a>
#  <img alt="" aria-busy="false" class="inline-block relative w-6 h-6 lazy-loaded" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/eojn00s72k70vnw5r0xj92t9e" src="https://media.licdn.com/dms/image/C510BAQGcSLTZcPdw-g/company-logo_100_100/0/1586848247435?e=2147483647&amp;v=beta&amp;t=RBpxjQJffTtMd3WADt4eoE6jBUEB_stRnqK7YGRybOM"/>
#  <div class="base-main-card__info self-center ml-1 flex-1 relative break-words papabear:min-w-0 mamabear:min-w-0 babybear:w-full">
#  <h3 class="base-main-card__title font-sans text-[18px] font-bold text-color-text overflow-hidden">
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 08,2023 19:56:22
#
#            </h3>
#  <h4 class="base-main-card__subtitle body-text text-color-text overflow-hidden">
#  <a class="hidden-nested-link outline-offset-[-1px]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs_main-jobs-card-subtitle" data-tracking-will-navigate="" href="https://in.linkedin.com/company/pago-analytics?trk=public_jobs_similar-jobs_main-jobs-card-subtitle">
#              PAGO Analytics
#            </a>
#  </h4>
#  <!-- -->
#  <div class="body-text text-color-text-low-emphasis base-main-card__metadata">
#  <span class="main-job-card__location block mb-0.5 text-md leading-open font-normal text-color-text-low-emphasis">
#              Hyderabad, Telangana, India
#            </span>
#  <!-- -->
#  <time class="main-job-card__listdate text-color-text-low-emphasis font-normal text-sm leading-open" datetime="2023-08-10">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        3 weeks ago
#
#            </time>
#  <!-- -->
#  </div>
#  </div>
#  <!-- -->
#  </div>
#  </li>
#  <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-main-card flex flex-wrap py-2 pr-2 babybear:pr-0 base-main-card--link main-job-card" data-entity-urn="urn:li:jobPosting:3703281001" data-impression-id="similar-jobs-10" data-reference-id="E1+mkhuEOyac0mRgdyDiSg==" data-tracking-id="/YoqrmJndWhgnuXVMzEEzA==">
#  <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs" data-tracking-will-navigate="" href="https://in.linkedin.com/jobs/view/software-engineering-internship-in-gurgaon-at-look-who-s-talking-at-look-who-s-talking-3703281001?refId=E1%2BmkhuEOyac0mRgdyDiSg%3D%3D&amp;trackingId=%2FYoqrmJndWhgnuXVMzEEzA%3D%3D&amp;trk=public_jobs_similar-jobs">
#  <span class="sr-only">
#
#
#          Software Engineering Internship in Gurgaon at Look Who's Talking
#
#
#            </span>
#  </a>
#  <img alt="" aria-busy="false" class="inline-block relative w-6 h-6 lazy-loaded" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/eojn00s72k70vnw5r0xj92t9e" src="https://media.licdn.com/dms/image/C4E0BAQEkSRCnSVtJlQ/company-logo_100_100/0/1629981389173?e=2147483647&amp;v=beta&amp;t=ZdZ7z2LVgCx5y_y9M2AUeZ5lPMyrpR2Z488rVECoLAk"/>
#  <div class="base-main-card__info self-center ml-1 flex-1 relative break-words papabear:min-w-0 mamabear:min-w-0 babybear:w-full">
#  <h3 class="base-main-card__title font-sans text-[18px] font-bold text-color-text overflow-hidden">
#
#          Software Engineering Internship in Gurgaon at Look Who's Talking
#
#            </h3>
#  <h4 class="base-main-card__subtitle body-text text-color-text overflow-hidden">
#  <a class="hidden-nested-link outline-offset-[-1px]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs_main-jobs-card-subtitle" data-tracking-will-navigate="" href="https://in.linkedin.com/company/look-who%27s-talking?trk=public_jobs_similar-jobs_main-jobs-card-subtitle">
#              Look Who's Talking
#            </a>
#  </h4>
#  <!-- -->
#  <div class="body-text text-color-text-low-emphasis base-main-card__metadata">
#  <span class="main-job-card__location block mb-0.5 text-md leading-open font-normal text-color-text-low-emphasis">
#              Gurgaon, Haryana, India
#            </span>
#  <!-- -->
#  <time class="main-job-card__listdate text-color-text-low-emphasis font-normal text-sm leading-open" datetime="2023-08-24">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        1 week ago
#
#            </time>
#  <!-- -->
#  </div>
#  </div>
#  <!-- -->
#  </div>
#  </li>
#  <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-main-card flex flex-wrap py-2 pr-2 babybear:pr-0 base-main-card--link main-job-card" data-entity-urn="urn:li:jobPosting:3685948346" data-impression-id="similar-jobs-11" data-reference-id="E1+mkhuEOyac0mRgdyDiSg==" data-tracking-id="SI4taTnCZPiFYmL0qi1mVQ==">
#  <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs" data-tracking-will-navigate="" href="https://in.linkedin.com/jobs/view/software-engineer-freshers-0-1-years-hyderabad-aug-03-2023-19-54-54-at-pago-analytics-3685948346?refId=E1%2BmkhuEOyac0mRgdyDiSg%3D%3D&amp;trackingId=SI4taTnCZPiFYmL0qi1mVQ%3D%3D&amp;trk=public_jobs_similar-jobs">
#  <span class="sr-only">
#
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 03,2023 19:54:54
#
#
#            </span>
#  </a>
#  <img alt="" aria-busy="false" class="inline-block relative w-6 h-6 lazy-loaded" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/eojn00s72k70vnw5r0xj92t9e" src="https://media.licdn.com/dms/image/C510BAQGcSLTZcPdw-g/company-logo_100_100/0/1586848247435?e=2147483647&amp;v=beta&amp;t=RBpxjQJffTtMd3WADt4eoE6jBUEB_stRnqK7YGRybOM"/>
#  <div class="base-main-card__info self-center ml-1 flex-1 relative break-words papabear:min-w-0 mamabear:min-w-0 babybear:w-full">
#  <h3 class="base-main-card__title font-sans text-[18px] font-bold text-color-text overflow-hidden">
#
#          Software Engineer (Freshers) 0-1 Years Hyderabad Aug 03,2023 19:54:54
#
#            </h3>
#  <h4 class="base-main-card__subtitle body-text text-color-text overflow-hidden">
#  <a class="hidden-nested-link outline-offset-[-1px]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs_main-jobs-card-subtitle" data-tracking-will-navigate="" href="https://in.linkedin.com/company/pago-analytics?trk=public_jobs_similar-jobs_main-jobs-card-subtitle">
#              PAGO Analytics
#            </a>
#  </h4>
#  <!-- -->
#  <div class="body-text text-color-text-low-emphasis base-main-card__metadata">
#  <span class="main-job-card__location block mb-0.5 text-md leading-open font-normal text-color-text-low-emphasis">
#              Hyderabad, Telangana, India
#            </span>
#  <!-- -->
#  <time class="main-job-card__listdate text-color-text-low-emphasis font-normal text-sm leading-open" datetime="2023-08-05">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        1 month ago
#
#            </time>
#  <!-- -->
#  </div>
#  </div>
#  <!-- -->
#  </div>
#  </li>
#  <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-main-card flex flex-wrap py-2 pr-2 babybear:pr-0 base-main-card--link main-job-card" data-entity-urn="urn:li:jobPosting:3700557101" data-impression-id="similar-jobs-12" data-reference-id="E1+mkhuEOyac0mRgdyDiSg==" data-tracking-id="eEMNsZXgGQj7V3VVvDUhag==">
#  <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs" data-tracking-will-navigate="" href="https://in.linkedin.com/jobs/view/software-developer-at-gururo-3700557101?refId=E1%2BmkhuEOyac0mRgdyDiSg%3D%3D&amp;trackingId=eEMNsZXgGQj7V3VVvDUhag%3D%3D&amp;trk=public_jobs_similar-jobs">
#  <span class="sr-only">
#
#
#          Software Developer
#
#
#            </span>
#  </a>
#  <img alt="" aria-busy="false" class="inline-block relative w-6 h-6 lazy-loaded" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/eojn00s72k70vnw5r0xj92t9e" src="https://media.licdn.com/dms/image/C560BAQGoaaRLSOzFOg/company-logo_100_100/0/1645303738334?e=2147483647&amp;v=beta&amp;t=cftRITYmLqiHk2EUlnmI_SXIq-LkPBD3qvJyH65B3ls"/>
#  <div class="base-main-card__info self-center ml-1 flex-1 relative break-words papabear:min-w-0 mamabear:min-w-0 babybear:w-full">
#  <h3 class="base-main-card__title font-sans text-[18px] font-bold text-color-text overflow-hidden">
#
#          Software Developer
#
#            </h3>
#  <h4 class="base-main-card__subtitle body-text text-color-text overflow-hidden">
#  <a class="hidden-nested-link outline-offset-[-1px]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs_main-jobs-card-subtitle" data-tracking-will-navigate="" href="https://in.linkedin.com/company/gururo?trk=public_jobs_similar-jobs_main-jobs-card-subtitle">
#              Gururo
#            </a>
#  </h4>
#  <!-- -->
#  <div class="body-text text-color-text-low-emphasis base-main-card__metadata">
#  <span class="main-job-card__location block mb-0.5 text-md leading-open font-normal text-color-text-low-emphasis">
#              Bangalore Urban, Karnataka, India
#            </span>
#  <!-- -->
#  <time class="main-job-card__listdate text-color-text-low-emphasis font-normal text-sm leading-open" datetime="2023-08-22">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        2 weeks ago
#
#            </time>
#  <!-- -->
#  </div>
#  </div>
#  <!-- -->
#  </div>
#  </li>
#  <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-main-card flex flex-wrap py-2 pr-2 babybear:pr-0 base-main-card--link main-job-card" data-entity-urn="urn:li:jobPosting:3677172805" data-impression-id="similar-jobs-13" data-reference-id="E1+mkhuEOyac0mRgdyDiSg==" data-tracking-id="zjKsXZEDBwGvvkOa4wjN0A==">
#  <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs" data-tracking-will-navigate="" href="https://in.linkedin.com/jobs/view/sde-1-at-masai-3677172805?refId=E1%2BmkhuEOyac0mRgdyDiSg%3D%3D&amp;trackingId=zjKsXZEDBwGvvkOa4wjN0A%3D%3D&amp;trk=public_jobs_similar-jobs">
#  <span class="sr-only">
#
#
#          SDE-1
#
#
#            </span>
#  </a>
#  <img alt="" aria-busy="false" class="inline-block relative w-6 h-6 lazy-loaded" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/eojn00s72k70vnw5r0xj92t9e" src="https://media.licdn.com/dms/image/C560BAQHdxMHntX6Z8Q/company-logo_100_100/0/1650372038245?e=2147483647&amp;v=beta&amp;t=_fCzxYZqA1IigSM4FHQMEZhyWh1cWhdbG7XibEekrqY"/>
#  <div class="base-main-card__info self-center ml-1 flex-1 relative break-words papabear:min-w-0 mamabear:min-w-0 babybear:w-full">
#  <h3 class="base-main-card__title font-sans text-[18px] font-bold text-color-text overflow-hidden">
#
#          SDE-1
#
#            </h3>
#  <h4 class="base-main-card__subtitle body-text text-color-text overflow-hidden">
#  <a class="hidden-nested-link outline-offset-[-1px]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs_main-jobs-card-subtitle" data-tracking-will-navigate="" href="https://in.linkedin.com/company/masai-school?trk=public_jobs_similar-jobs_main-jobs-card-subtitle">
#              Masai
#            </a>
#  </h4>
#  <!-- -->
#  <div class="body-text text-color-text-low-emphasis base-main-card__metadata">
#  <span class="main-job-card__location block mb-0.5 text-md leading-open font-normal text-color-text-low-emphasis">
#              Bengaluru North, Karnataka, India
#            </span>
#  <!-- -->
#  <time class="main-job-card__listdate text-color-text-low-emphasis font-normal text-sm leading-open" datetime="2023-07-31">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        1 month ago
#
#            </time>
#  <!-- -->
#  </div>
#  </div>
#  <!-- -->
#  </div>
#  </li>
#  <li>
#  <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-main-card flex flex-wrap py-2 pr-2 babybear:pr-0 base-main-card--link main-job-card" data-entity-urn="urn:li:jobPosting:3694960968" data-impression-id="similar-jobs-14" data-reference-id="E1+mkhuEOyac0mRgdyDiSg==" data-tracking-id="Cbj18s8D+zMiRyLBdYu0ng==">
#  <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_similar-jobs" data-tracking-will-navigate="" href="https://in.linkedin.com/jobs/view/frontend-developer-sde-1-at-eshopbox-3694960968?refId=E1%2BmkhuEOyac0mRgdyDiSg%3D%3D&amp;trackingId=Cbj18s8D%2BzMiRyLBdYu0ng%3D%3D&amp;trk=public_jobs_similar-jobs">
#  <span class="sr-only">
#
#
#          Frontend Developer (SDE 1)
#
#
#            </span>
#  </a>
#  <img alt="" aria-busy="false" class="inline-block relative w-6 h-6 lazy-loaded" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/eojn00s72k70vnw5r0xj92t9e" src="https://media.licdn.com/dms/image/C560BAQFJk8h9TT-cZA/company-logo_100_100/0/1604293079707?e=2147483647&amp;v=beta&amp;t=lZyAxD5-tzv9mnEsSaHoYOBHhlzJskthv49l0hePz_k"/>
# ...
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="العربية (Arabic)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="ar_AE" data-tracking-control-name="language-selector-ar_AE" lang="ar_AE" role="menuitem">
#                  العربية (Arabic)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Čeština (Czech)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="cs_CZ" data-tracking-control-name="language-selector-cs_CZ" lang="cs_CZ" role="menuitem">
#                  Čeština (Czech)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Dansk (Danish)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="da_DK" data-tracking-control-name="language-selector-da_DK" lang="da_DK" role="menuitem">
#                  Dansk (Danish)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Deutsch (German)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="de_DE" data-tracking-control-name="language-selector-de_DE" lang="de_DE" role="menuitem">
#                  Deutsch (German)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="English (English) selected" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link--selected" data-locale="en_US" data-tracking-control-name="language-selector-en_US" lang="en_US" role="menuitem">
#  <strong>English (English)</strong>
#  </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Español (Spanish)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="es_ES" data-tracking-control-name="language-selector-es_ES" lang="es_ES" role="menuitem">
#                  Español (Spanish)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Français (French)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="fr_FR" data-tracking-control-name="language-selector-fr_FR" lang="fr_FR" role="menuitem">
#                  Français (French)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="हिंदी (Hindi)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="hi_IN" data-tracking-control-name="language-selector-hi_IN" lang="hi_IN" role="menuitem">
#                  हिंदी (Hindi)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Bahasa Indonesia (Indonesian)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="in_ID" data-tracking-control-name="language-selector-in_ID" lang="in_ID" role="menuitem">
#                  Bahasa Indonesia (Indonesian)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Italiano (Italian)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="it_IT" data-tracking-control-name="language-selector-it_IT" lang="it_IT" role="menuitem">
#                  Italiano (Italian)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="日本語 (Japanese)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="ja_JP" data-tracking-control-name="language-selector-ja_JP" lang="ja_JP" role="menuitem">
#                  日本語 (Japanese)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="한국어 (Korean)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="ko_KR" data-tracking-control-name="language-selector-ko_KR" lang="ko_KR" role="menuitem">
#                  한국어 (Korean)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Bahasa Malaysia (Malay)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="ms_MY" data-tracking-control-name="language-selector-ms_MY" lang="ms_MY" role="menuitem">
#                  Bahasa Malaysia (Malay)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Nederlands (Dutch)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="nl_NL" data-tracking-control-name="language-selector-nl_NL" lang="nl_NL" role="menuitem">
#                  Nederlands (Dutch)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Norsk (Norwegian)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="no_NO" data-tracking-control-name="language-selector-no_NO" lang="no_NO" role="menuitem">
#                  Norsk (Norwegian)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Polski (Polish)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="pl_PL" data-tracking-control-name="language-selector-pl_PL" lang="pl_PL" role="menuitem">
#                  Polski (Polish)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Português (Portuguese)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="pt_BR" data-tracking-control-name="language-selector-pt_BR" lang="pt_BR" role="menuitem">
#                  Português (Portuguese)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Română (Romanian)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="ro_RO" data-tracking-control-name="language-selector-ro_RO" lang="ro_RO" role="menuitem">
#                  Română (Romanian)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Русский (Russian)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="ru_RU" data-tracking-control-name="language-selector-ru_RU" lang="ru_RU" role="menuitem">
#                  Русский (Russian)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Svenska (Swedish)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="sv_SE" data-tracking-control-name="language-selector-sv_SE" lang="sv_SE" role="menuitem">
#                  Svenska (Swedish)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="ภาษาไทย (Thai)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="th_TH" data-tracking-control-name="language-selector-th_TH" lang="th_TH" role="menuitem">
#                  ภาษาไทย (Thai)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Tagalog (Tagalog)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="tl_PH" data-tracking-control-name="language-selector-tl_PH" lang="tl_PH" role="menuitem">
#                  Tagalog (Tagalog)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Türkçe (Turkish)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="tr_TR" data-tracking-control-name="language-selector-tr_TR" lang="tr_TR" role="menuitem">
#                  Türkçe (Turkish)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="Українська (Ukrainian)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="uk_UA" data-tracking-control-name="language-selector-uk_UA" lang="uk_UA" role="menuitem">
#                  Українська (Ukrainian)
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="简体中文 (Chinese (Simplified))" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="zh_CN" data-tracking-control-name="language-selector-zh_CN" lang="zh_CN" role="menuitem">
#                  简体中文 (Chinese (Simplified))
#              </button>
#  </li>
#  <li class="language-selector__item" role="presentation">
#  <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#  <button aria-label="正體中文 (Chinese (Traditional))" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="zh_TW" data-tracking-control-name="language-selector-zh_TW" lang="zh_TW" role="menuitem">
#                  正體中文 (Chinese (Traditional))
#              </button>
#  </li>
#  <!-- -->
#  </ul>]

# %%
import pandas as pd

cols=['Title','Company','Location','Date','Posted']
df = pd.DataFrame(list(zip(title,Company_Name,Location,time,date)),
               columns =cols)
df
# Out:
#                                    Title  \
# 0       Junior Data Scientist - IIT/BITS
# 1           Artificial Intelligence Role
# 2                   AI/ML Data Scientist
# 3                          NLTK, CORENLP
# 4    Deep Learning Engineer (Internship)
# ..                                   ...
# 168                   Process Automation
# 169                        AI-Evangelist
# 170   Machine Learning Researcher Intern
# 171                           AI/ML Data
# 172   Machine Learning Engineer - 300823
#
#                                                Company  \
# 0            Whitetable.ai (Previously as IIE Network)
# 1    Dubai Jobs, Gulf Jobs, Jobs in Dubai, Qatar, K...
# 2                                              Experfy
# 3                                  Zensar Technologies
# 4                                           HyperVerge
# ..                                                 ...
# 168                                      Tech Mahindra
# 169                                             Icreon
# 170          Fynd (Shopsense Retail Technologies Ltd.)
# 171                                           Anicalls
# 172                                             Sirion
#
#                                       Location          Date      Posted
# 0                  Bengaluru, Karnataka, India   1 month ago  2023-08-05
# 1                   Mumbai, Maharashtra, India   1 month ago  2023-08-04
# 2                  Bengaluru, Karnataka, India  3 months ago  2023-05-20
# 3                   Pune/Pimpri-Chinchwad Area    5 days ago  2023-08-31
# 4                  Bengaluru, Karnataka, India  2 months ago  2023-06-26
# ..                                         ...           ...         ...
# 168                Bengaluru, Karnataka, India     1 day ago  2023-09-04
# 169                Noida, Uttar Pradesh, India   1 month ago  2023-07-17
# 170                 Mumbai, Maharashtra, India    1 week ago  2023-08-24
# 171  Gautam Buddha Nagar, Uttar Pradesh, India   1 month ago  2023-08-06
# 172                   Gurugram, Haryana, India    4 days ago  2023-09-01
#
# [173 rows x 5 columns]

# %%
span

# %%
data[0]

# %%
data[6].find('span',class_='result-benefits__text').get_text()

# %%
h=soup.findall('div',class_='result-benefits__text')
h
# hire=i.find('span',class_='result-benefits__text').get_text()
# hiring.append(hire.strip())

# %%
<span class="result-benefits__text">
         Be an early applicant
<!---->      </span>

# %%
import pandas as pd

cols=['Title','Description','Location','Hiring','Date','Posted']
df = pd.DataFrame(list(zip(title,desc,span,hiring,time,date)),
               columns =cols)
df

# %%
Location

# %%
h3=soup.findAll('h3', class_='base-search-card__title')
h3

# title.append(h3.strip())

# %%
h3.source

# %%
dir(h3)

# %%
for i in h3:
    print(i)

# %%
title

# %%
len(selector)

# %%
selector

# %%
i.find('a',class_='hidden-nested-link').get_text()

# %%
<a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/robert-half-international?trk=public_jobs_jserp-result_job-search-card-subtitle">
            Robert Half
          </a>

# %%
import pandas as pd

cols=['Title','Description','Location','Hiring','Date','Posted']
df = pd.DataFrame(list(zip(title,desc,span,hiring,time,date)),
               columns =cols)
df

# %%
dir(By)

# %%
wd=webdriver.Chrome()
wd.get('https://ca.linkedin.com/jobs/canada-jobs-jobs?keywords=Canada%20Jobs&location=Canada&locationId=&geoId=101174742&f_TPR=r2592000&position=1&pageNum=0')

timelib.sleep(2)
scroll_pause_time = 1 
screen_height = wd.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1
element=wd.find_element(By.TAG_NAME,'HTML')
while True:
    # scroll one screen height each time
    driver.execute_script("window.scrollTo(0, {screen_height}*{i});".format(screen_height=screen_height, i=i))  
    i += 1
    timelib.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break
        
# for i in range(5):
#     element.send_keys('PAGE_DOWN')
#     timelib.sleep(3)
source=wd.page_source
# wd.quit()

# %%
dir(element)

# %%
# driver = webdriver.Chrome(executable_path=r"E:\Chromedriver\chromedriver_win32_chrome83\chromedriver.exe")
# driver.get("https://www.reddit.com/search/?q=r%2FCOVID19")
time.sleep(2)  # Allow 2 seconds for the web page to open
scroll_pause_time = 1 # You can set your own pause time. My laptop is a bit slow so I use 1 sec
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1

while True:
    # scroll one screen height each time
    driver.execute_script("window.scrollTo(0, {screen_height}*{i});".format(screen_height=screen_height, i=i))  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break

# %%
wd.current_window_handle

# %%
help(wd.current_window_handle)

# %%
dir(wd)

# %%
len(source)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(source, 'lxml')

# %%
job=[]
selector = soup.find_all('div', class_='base-search-card__info')

# %%
title=[]
desc=[]
span=[]
hiring=[]
time=[]
date=[]

for i in soup.findAll('time'):
        if i.has_attr('datetime'):
            time.append(i.get_text().strip())
            date.append(i['datetime'])

for i in selector:
    
    h3=i.find('h3', class_='base-search-card__title').get_text()
    title.append(h3.strip())
    
    h4=i.find('h4', class_='base-search-card__subtitle').get_text()
    desc.append(h4.strip())
    
    spanl=i.find('span', class_="job-search-card__location").get_text()
    span.append(spanl.strip())
    
    hire=i.find('span',class_='result-benefits__text').get_text()
    hiring.append(hire.strip())

# %%
for i in soup.findAll('time'):
        if i.has_attr('datetime'):
            print(i.get_text().strip())
            print(i['datetime'])

# %%
<time class="job-search-card__listdate--new" datetime="2022-08-20">

# %%
selector

# %%
print(soup.get_text())

# %%
selector

# %%
dir(selector)

# %%
for i in selector:
    print(type(i))

# %%
from selenium import webdriver

options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
options.add_argument('--headless')

driver = webdriver.Chrome()
import time

driver.get("https://www.tripadvisor.com/Airline_Review-d8729157-Reviews-Spirit-Airlines#REVIEWS")
more_buttons = driver.find_elements("moreLink")
for x in range(len(more_buttons)):
  if more_buttons[x].is_displayed():
      driver.execute_script("arguments[0].click();", more_buttons[x])
      time.sleep(1)
page_source = driver.page_source
from bs4 import BeautifulSoup

soup = BeautifulSoup(page_source, 'lxml')
reviews = []
reviews_selector = soup.find_all('div', class_='reviewSelector')
for review_selector in reviews_selector:
    review_div = review_selector.find('div', class_='dyn_full_review')
    if review_div is None:
        review_div = review_selector.find('div', class_='basic_review')
    review = review_div.find('div', class_='entry').find('p').get_text()
    review = review.strip()
    reviews.append(review)

# %%
reviews

# %%
wd.current_url="https://ca.linkedin.com/jobs/canada-jobs-jobs"

# %%
dir(wd)

# %%
dir(el)

# %%
help(el.click)

# %%
dir(Keys)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver = webdriver.Chrome()

    # Navigate to url
driver.get("http://www.google.com")
    # Store 'SearchInput' element
SearchInput = driver.find_element(By.NAME, "q")
SearchInput.send_keys("selenium")
    # Clears the entered text
# SearchInput.clear()

# %%
help(wd.find_elements_by_id)

# %%
wd=webdriver.Chrome()
wd.get("https://ca.linkedin.com/jobs/canada-jobs-jobs")

# %%
dir(wd)

# %%
help(wd.find_element)

# %%
<input id="username" name="session_key" type="text" aria-describedby="error-for-username" required="" validation="email|tel" class="" autofocus="" aria-label="Email or Phone">

# %%
el

# %%
from selenium import webdriver

options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
options.add_argument('--headless')
driver = webdriver.Chrome()

# %%
dir(webdriver)

# %%
import selenium as sel
from selenium import webdriver

# %%
dir(sel)

# %%
dir(sel.webdriver)

# %%
dir(obj)

# %%
import time
obj=webdriver.Chrome()
obj.get('https://www.linkedin.com/jobs/search/?currentJobId=3211654034&distance=25&f_T=9&geoId=101174742&keywords=canada%20jobs')

time.sleep(5)
obj.close()

# %%
pip -V

# %%
from selenium import webdriver

# %%
options = webdriver.ChromeOptions()

# %%
dir(options)

# %%
options.binary_location=r"\Users\Slmss\Desktop\chromedriver.exe"

# %%
help(options.browser_version)

# %%
x=options.browser_version

# %%
options.browserVersion

# %%
options.Chrome()

# %%
x=webdriver.Chrome()
x.quit()

# %%
dir(x)

# %%
options.get();

# %%
pip install bs4 selenium

# %%
from selenium import webdriver

options = webdriver.ChromeOptions()

# %%
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
options.add_argument('--headless')

# %%
import time

from selenium import webdriver


driver = webdriver.Chrome(r"\Users\Slmss\Desktop\chromedriver.exe")  # Optional argument, if not specified will search path.

driver.get();

time.sleep(5) # Let the user actually see something!

search_box = driver.find_element_by_name('q')

search_box.send_keys('ChromeDriver')

search_box.submit()

time.sleep(5) # Let the user actually see something!

driver.quit()

# %%
import time

from selenium import webdriver

from selenium.webdriver.chrome.service import Service

service = Service(r"\Users\Slmss\Desktop\chromedriver.exe")

service.start()

driver = webdriver.Remote(service.service_url)

driver.get('http://www.google.com/');

time.sleep(5) # Let the user actually see something!

driver.quit()

# %%
driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver", chrome_options=options)

# %%
pip uninstall selenium

# %%
from selenium import webdriver


driver = webdriver.Chrome()

driver.get("http://facebook.com")

# driver.quit()

# %% [raw]
# dir(

# %%
driver=webdriver.Chrome()

# %%
help(webdriver.Chrome)

# %%
dir(webdriver)

# %%
import

# %%
selenium.__version__
